# %% [markdown]
# # 1. NICE Biz info 기업정보 데이터
# https://www.nicebizinfo.com/cm/CM0100M001GE.nice
#     ![image.png](attachment:image.png)
#     ![image.png](attachment:image.png)
#     ![image.png](attachment:image.png)

# %% [markdown]
# ## 데이터 불러오기 f_index[2] : 11903개

# %%
import pandas as pd
bizinfo=pd.read_excel('C:/Users/shcho/Desktop/윤영/sesac/공모전/공통깃헙/ACSM/biz_info result/bizinfo_df_findex2_11903.xlsx',index_col=0)
bizinfo.head()
# Out:
#    cmp_number                              address                  industry  \
# 0  4128801501  경기 김포시 김포대로 709, 퍼스트블루 1008호, 1009호   (L68121)주거용 건물 개발 및 공급업
# 1  4128801699                경기 오산시 세남로 72, 본관동 2층       (L68112)비주거용 건물 임대업
# 2  4138104123            전남 담양군 대전면 중옥길 41-8, 206호         (F41220)토목시설물 건설업
# 3  4138501691                전남 여수시 율촌면 여순로 607-12  (C10220)수산식물 가공 및 저장 처리업
# 4  4138600291   서울 영등포구 여의대방로 386, 302호 301호, 302호         (G46800)상품 종합 도매업
#
#    ind_rank                  payroll   new_payroll         employee  \
# 0       6.0  4,000만원 이상 ~ 6,000만원 미만  ~ 4,000만원 미만   1명 이상 ~ 20명 미만
# 1       6.0                      NaN           NaN              NaN
# 2       6.0             ~ 4,000만원 미만  ~ 4,000만원 미만  40명 이상 ~ 70명 미만
# 3       6.0             ~ 4,000만원 미만  ~ 4,000만원 미만   1명 이상 ~ 20명 미만
# 4       5.0             ~ 4,000만원 미만  ~ 4,000만원 미만  20명 이상 ~ 40명 미만
#
#                                           employment  \
# ...

# %% [markdown]
# - 총 11903개 데이터

# %%
len(bizinfo)
# Out:
# 11903

# %% [markdown]
# ## 결측치 확인

# %%
pd.DataFrame(bizinfo.isnull().sum(),columns=['null 개수'])
# Out:
#              null 개수
# cmp_number         0
# address          462
# industry         461
# ind_rank         989
# payroll         2558
# new_payroll     2558
# employee        2558
# employment      2558
# resignation     2558
# cmp_years       2558

# %% [markdown]
# ### 사업자등록번호로 조회시, 아예 검색조회 안되는 경우 462건
# ![image.png](attachment:image.png)

# %%
bizinfo[bizinfo['address'].isnull()]
# Out:
#        cmp_number address industry  ind_rank payroll new_payroll employee  \
# 17     4148107593     NaN      NaN       NaN     NaN         NaN      NaN
# 18     4148500415     NaN      NaN       NaN     NaN         NaN      NaN
# 189    4168500070     NaN      NaN       NaN     NaN         NaN      NaN
# 190    4168501104     NaN      NaN       NaN     NaN         NaN      NaN
# 192    4168504697     NaN      NaN       NaN     NaN         NaN      NaN
# ...           ...     ...      ...       ...     ...         ...      ...
# 11754  8858500897     NaN      NaN       NaN     NaN         NaN      NaN
# 11795  8898500429     NaN      NaN       NaN     NaN         NaN      NaN
# 11825  8928500371     NaN      NaN       NaN     NaN         NaN      NaN
# 11844  8948500436     NaN      NaN       NaN     NaN         NaN      NaN
# 11854  8958500235     NaN      NaN       NaN     NaN         NaN      NaN
#
#       employment resignation cmp_years
# 17           NaN         NaN       NaN
# ...

# %%
bizinfo[bizinfo['industry'].isnull()]
# Out:
#        cmp_number address industry  ind_rank payroll new_payroll employee  \
# 17     4148107593     NaN      NaN       NaN     NaN         NaN      NaN
# 18     4148500415     NaN      NaN       NaN     NaN         NaN      NaN
# 189    4168500070     NaN      NaN       NaN     NaN         NaN      NaN
# 190    4168501104     NaN      NaN       NaN     NaN         NaN      NaN
# 192    4168504697     NaN      NaN       NaN     NaN         NaN      NaN
# ...           ...     ...      ...       ...     ...         ...      ...
# 11754  8858500897     NaN      NaN       NaN     NaN         NaN      NaN
# 11795  8898500429     NaN      NaN       NaN     NaN         NaN      NaN
# 11825  8928500371     NaN      NaN       NaN     NaN         NaN      NaN
# 11844  8948500436     NaN      NaN       NaN     NaN         NaN      NaN
# 11854  8958500235     NaN      NaN       NaN     NaN         NaN      NaN
#
#       employment resignation cmp_years
# 17           NaN         NaN       NaN
# ...

# %% [markdown]
# ### 사업자등록번호로 조회는 되지만 주소가 없는 데이터도 존재
# - address	462
# - industry	461
# - 1개의 차이가 나는 이유
#
# ![image.png](attachment:image.png)

# %%
bizinfo[(bizinfo['address'].isnull()) & (bizinfo['industry'].notnull())]
# Out:
#       cmp_number address         industry  ind_rank payroll new_payroll  \
# 2696  5108119835     NaN  (D35114)태양력 발전업       5.0     NaN         NaN
#
#      employee employment resignation cmp_years
# 2696      NaN        NaN         NaN       NaN

# %% [markdown]
# ### 주소, 산업분류는 있지만 [기업정보 상세보기] 내역이 존재하지 않는 데이터도 있음 : 528개
#
#
# ![image.png](attachment:image.png)

# %%
bizinfo[(bizinfo['ind_rank'].isnull()) & (bizinfo['industry'].notnull())]
# Out:
#        cmp_number                                         address  \
# 21     4148601482  서울 강서구 공항대로 219, 514호,515호,516호,517호,518호,519호
# 54     4158600453                              서울 중구 을지로5길 16, 7층
# 68     4168102162                               전남 광양시 길호1길 1, 3층
# 81     4168110492                             전남 광양시 제철로 1655-251
# 148    4168166322       충남 당진시 송악읍 북부산업로 1480, 305호 현대제철주식회사 한가족관
# ...           ...                                             ...
# 11820  8918601753                              경기 안산시 단원구 신원로 355
# 11839  8948100743                    서울 강남구 언주로86길 5, 5층 501호, 7층
# 11845  8948600020                               울산 울주군 언양읍 고하길 85
# 11895  8988800759                               경기 김포시 대곶면 율마로 26
# 11899  8998701263                                서울 영등포구 의사당대로 82
#
#                         industry  ind_rank       payroll   new_payroll  \
# 21                     전자상거래 소매업       NaN           NaN           NaN
# ...
